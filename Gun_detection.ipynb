# %%
# !git clone https://github.com/ultralytics/yolov5
# !cd yolov5
# !pip install -r requirements.txt

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="n9KvsujbU5gFD867E9sv")
project = rf.workspace("yolov7test-u13vc").project("weapon-detection-m7qso")
version = project.version(16)
dataset = version.download("yolov5")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to weapon-detection-16 in yolov5pytorch:: 100%|██████████| 33250/33250 [00:06<00:00, 5148.53it/s]

# %%
# %cd /content/yolov5
# Out:
# /content/yolov5

# %%
# !python train.py --img 640 --batch 3 --epochs 5 --data /content/weapon-detection-16/data.yaml --weights yolov5m.pt
# Out:
# Streaming output truncated to the last 5000 lines.
#   with torch.cuda.amp.autocast(amp):
#         4/4      1.67G    0.03449    0.01829   0.004824          5        640:  31% 1143/3634 [03:10<07:47,  5.33it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         4/4      1.67G    0.03447    0.01828   0.004821          4        640:  31% 1144/3634 [03:11<07:45,  5.35it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         4/4      1.67G    0.03448    0.01829    0.00482          9        640:  32% 1145/3634 [03:11<07:57,  5.21it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
# ...
